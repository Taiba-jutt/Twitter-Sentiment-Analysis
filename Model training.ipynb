# %%
# !pip install flask scikit-learn
# Out:
# Requirement already satisfied: flask in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (3.1.0)
# Requirement already satisfied: scikit-learn in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (1.6.1)
# Requirement already satisfied: Werkzeug>=3.1 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from flask) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.2 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from flask) (1.9.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: colorama in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from click>=8.1.3->flask) (0.4.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\anaconda3\anacondaa python\lib\site-packages (from Jinja2>=3.1.2->flask) (3.0.2)

# %%
import pickle
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression

texts = ["I love this", "I hate this"]
labels = [1, 0]

vectorizer = TfidfVectorizer()
X = vectorizer.fit_transform(texts)

model = LogisticRegression()
model.fit(X, labels)

pickle.dump(model, open("sentiment_model.pkl", "wb"))
pickle.dump(vectorizer, open("vectorizer.pkl", "wb"))

print("Files saved")
# Out:
# Files saved

# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'ANN.ipynb',
#  'Arooj 28 (ANN).ipynb',
#  'best_classification_model.joblib',
#  'clusters_pca.png',
#  'CNN.ipynb',
#  'Correlation Analysis.ipynb',
#  'FINAL_USO_cleaned.csv',
#  'Logistic Regression and random Forest.ipynb',
#  'Model Evaluation (Reflection).docx',
#  'Model Evaluation.ipynb',
#  'Model training.ipynb',
#  'Nadia  20(ANN) .ipynb',
#  'NLP.ipynb',
#  'Regression Model.ipynb',
#  'scaler.joblib',
#  'sentiment_model.pkl',
#  'student_performance_dataset_cleaned.csv',
#  'Taiba 26 Correlation Analysis Report.docx',
#  'titanic.csv',
#  'Titanic.ipynb',
#  'Tweets.csv',
#  'Tweets.ipynb',
#  'Tweets_cleaned.csv',
#  'Unsupervised Learning.ipynb',
#  'Untitled.ipynb',
#  'vectorizer.pkl']
